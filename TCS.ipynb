# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from datetime import datetime, date, timedelta
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

# %%
# for stock data
stock_data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Dissertation/Comparison-of-effect-of-Inflation-in-Stock-market-Indices/India/TCS.csv", index_col=0, parse_dates=[0], dayfirst=True,
                         header=0, names=['Date', 'open', 'high', 'low', 'close', 'volume'])

# for index data
# pd.read_csv("C:/Users/HP/OneDrive/Desktop/Dissertation/Comparison-of-effect-of-Inflation-in-Stock-market-Indices/S&P500.csv", index_col=0, parse_dates=[0], dayfirst=True,
#                          header=0, names=['Date', 'open', 'high', 'low', 'close', 'adj_close', 'volume'])

stock_data.index = stock_data.index.strftime("%Y-%m")
stock_data.index = pd.to_datetime(stock_data.index)
stock_data = stock_data.sort_index()
print("Stock data\n")
print(stock_data.head())
# Out:
# Stock data
#
#                open      high       low     close    volume
# Date
# 2005-02-01  163.125  177.5000  161.0000  172.6126  38014680
# 2005-03-01  172.250  184.3750  168.8876  179.0938  33676128
# 2005-04-01  178.750  182.0000  136.3750  141.2814  73302288
# 2005-05-01  141.250  167.9938  138.1376  166.9000  48088784
# 2005-06-01  166.225  169.8750  157.5000  168.9876  40496912
# C:\Users\HP\AppData\Local\Temp\ipykernel_5052\121996965.py:2: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock_data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Dissertation/Comparison-of-effect-of-Inflation-in-Stock-market-Indices/India/TCS.csv", index_col=0, parse_dates=[0], dayfirst=True,

# %%
inflation_data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Dissertation/Comparison-of-effect-of-Inflation-in-Stock-market-Indices/inflation rate 2000-2023.csv")

inflation_data = inflation_data.set_index('Date')
inflation_data.index = pd.to_datetime(inflation_data.index)
print("Inflation data\n")
print(inflation_data.head())
# Out:
# Inflation data
#
#             us_inflation_rate  us_share_price  china_inflation_rate  \
# Date
# 2000-01-01           2.738892        39.55779                  -0.2
# 2000-02-01           3.221884        43.48396                   0.7
# 2000-03-01           3.757576        46.61248                  -0.2
# 2000-04-01           3.068592        49.17913                  -0.3
# 2000-05-01           3.188929        49.00218                   0.1
#
#             china_share_price  india_inflation_rate  india_share_price
# Date
# 2000-01-01           19.75834              2.619048           62.86602
# 2000-02-01           20.65533              3.614458           59.92387
# 2000-03-01           19.18312              4.830918           61.62468
# 2000-04-01           17.93419              5.542169           64.01819
# 2000-05-01           15.61101              5.011933           63.33833

# %%
data = pd.concat([stock_data,
                  inflation_data.loc[:, ['india_inflation_rate', 'india_share_price']]],
                  axis='columns')

data.index = pd.to_datetime(data.index)

data = data.dropna()

data.head()
# Out:
#                open      high       low     close      volume  \
# Date
# 2005-02-01  163.125  177.5000  161.0000  172.6126  38014680.0
# 2005-03-01  172.250  184.3750  168.8876  179.0938  33676128.0
# 2005-04-01  178.750  182.0000  136.3750  141.2814  73302288.0
# 2005-05-01  141.250  167.9938  138.1376  166.9000  48088784.0
# 2005-06-01  166.225  169.8750  157.5000  168.9876  40496912.0
#
#             india_inflation_rate  india_share_price
# Date
# 2005-02-01              4.166667           67.84700
# 2005-03-01              4.166667           68.08076
# 2005-04-01              4.960318           66.29041
# 2005-05-01              3.740157           66.47942
# 2005-06-01              3.320313           67.79820

# %%
def plot_price(column):
    plt.figure(figsize=(15, 7))
    sns.lineplot(data=column, x=column.index, y=column, color="midnightblue")
    plt.title(f"{column.name} price distribution from 2000-present")
    plt.ylabel(f"{column.name} price")
    for yr in range(column.index[0].year, column.index[-1].year):
        plt.axvline(pd.to_datetime(str(yr)+'-01-01'), color='black', ls="--", alpha=0.3)
    plt.show()

# %%
for col in data.columns:
    plot_price(data[col])

# %%
close_data = data['close'].diff().dropna()
open_data = data['open'].diff().dropna()
high_data = data['high'].diff().dropna()
low_data = data['low'].diff().dropna()
volume_data = data['volume'].diff().dropna()
india_inflation_rate_data = data['india_inflation_rate'].diff().dropna()
india_share_price_data = data['india_share_price'].diff().dropna()

# %%
for col in data.columns.values:
    col_name = globals()[f'{col}_data']
    plot_price(col_name)

# %%
close_std = close_data.groupby([close_data.index.year]).std()
open_std = open_data.groupby([open_data.index.year]).std()
high_std = high_data.groupby([high_data.index.year]).std()
low_std = low_data.groupby([low_data.index.year]).std()
volume_std = volume_data.groupby([volume_data.index.year]).std()
india_inflation_rate_std = india_inflation_rate_data.groupby([india_inflation_rate_data.index.year]).std()
india_share_price_std = india_share_price_data.groupby([india_share_price_data.index.year]).std()

close_volatility = close_data.index.map(lambda dt: close_std.loc[dt.year])
open_volatility = open_data.index.map(lambda dt: open_std.loc[dt.year])
high_volatility = high_data.index.map(lambda dt: high_std.loc[dt.year])
low_volatility = low_data.index.map(lambda dt: low_std.loc[dt.year])
volume_volatility = volume_data.index.map(lambda dt: volume_std.loc[dt.year])
india_inflation_rate_volatility = india_inflation_rate_data.index.map(lambda dt: india_inflation_rate_std.loc[dt.year])
india_share_price_volatility = india_share_price_data.index.map(lambda dt: india_share_price_std.loc[dt.year])

close_data = pd.Series(close_data / close_volatility, name='close')
open_data = pd.Series(open_data / open_volatility, name='open')
high_data = pd.Series(high_data / high_volatility, name='high')
low_data = pd.Series(low_data / low_volatility, name='low')
volume_data = pd.Series(volume_data / volume_volatility, name='volume')
india_inflation_rate_volatility = pd.Series(india_inflation_rate_data / india_inflation_rate_volatility, name='inflation_rate')
india_share_price_volatility = pd.Series(india_share_price_data / india_share_price_volatility, name='share_price')

# %%
for col in data.columns.values:
    col_name = globals()[f'{col}_data']
    plot_price(col_name)

# %%
final_data = pd.DataFrame({'open': open_data.values,
                           'high': high_data.values,
                           'low': low_data.values,
                           'close': close_data.values,
                           'volume': volume_data.values,
                           'india_inflation_rate': india_inflation_rate_data,
                           'india_share_price': india_share_price_data},
                            index=data.index[1:])

# %%
start_date = final_data.index[0].date()
end_date = date(2022, 12, 1)

month_diff = math.ceil((end_date - start_date).days / 30)
train_start_idx = final_data.index[0]
train_end_idx = final_data.index[month_diff]

test_start_idx = final_data.index[month_diff+1]


x = ['open', 'high', 'low', 'volume', 'india_inflation_rate', 'india_share_price']
y = ['close']

train_data = final_data[:train_end_idx]
test_data = final_data[test_start_idx:]

# %%
arima_model = ARIMA(endog=train_data.loc[:, y],
                    exog=train_data.loc[:, x],
                    order=(1, 0, 1))

model_fit = arima_model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                  218
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -180.885
# Date:                Wed, 22 Nov 2023   AIC                            381.770
# Time:                        09:40:16   BIC                            415.615
# Sample:                    03-01-2005   HQIC                           395.440
#                          - 04-01-2023
# Covariance Type:                  opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0184      0.027      0.682      0.495      -0.034       0.071
# open                    -0.5210      0.061     -8.481      0.000      -0.641      -0.401
# high                     0.5963      0.048     12.489      0.000       0.503       0.690
# low                      0.5380      0.053     10.145      0.000       0.434       0.642
# volume                  -0.0452      0.056     -0.813      0.416      -0.154       0.064
# india_inflation_rate    -0.0466      0.038     -1.237      0.216      -0.120       0.027
# india_share_price        0.0161      0.013      1.258      0.208      -0.009       0.041
# ar.L1                   -0.1801      0.186     -0.968      0.333      -0.545       0.184
# ma.L1                   -0.2610      0.184     -1.418      0.156      -0.622       0.100
# sigma2                   0.3075      0.033      9.404      0.000       0.243       0.372
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.44
# Prob(Q):                              0.93   Prob(JB):                         0.80
# Heteroskedasticity (H):               0.91   Skew:                             0.11
# Prob(H) (two-sided):                  0.70   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predicted_close = model_fit.predict(start=test_data.index[0],
                                    end=test_data.index[-1],
                                    exog=test_data.loc[:, x])

residuals = test_data['close'].values - predicted_close

# get the RMSE value to see how well the model performed

print(f"Root Mean Square Error: {np.sqrt(np.mean(residuals**2))}")
# Out:
# Root Mean Square Error: 0.8134828302312829

# %%
plt.figure(figsize=(12, 4))
plt.plot(test_data['close'], color='dodgerblue')
plt.plot(predicted_close, color='springgreen')

plt.legend(('Actual', 'Predicted'), fontsize=15)
plt.tight_layout()
plt.show()
